# %% [markdown]
# #**Give** folder path of Dataset

# %%
import os,shutil
from IPython.core.magic import register_line_cell_magic
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Creating Required Directory 
drive_path='/content/drive/MyDrive/'
main_directory='/content/drive/MyDrive/Yolo_tiny'
try:
  os.mkdir(os.path.join(main_directory))
  os.mkdir(os.path.join(main_directory,"input_video"))
  os.mkdir(os.path.join(main_directory,"output_video"))
  os.mkdir(os.path.join(main_directory,"models"))

except:
  print("Directory Already Exists !!!")
# Out:
# Directory Already Exists !!!

# %% [markdown]
# # Configuring cuDNN on Colab for YOLOv4

# %%
os.chdir(main_directory)

# !/usr/local/cuda/bin/nvcc --version    # CUDA: Let's check that Nvidia CUDA drivers are already pre-installed and which version is it.
# !nvidia-smi                            # Current Available GPU information

## This cell ensures you have the correct architecture for your respective GPU; If you command is not found, look through these GPUs, find the respective
os.environ['GPU_TYPE'] = str(os.popen('nvidia-smi --query-gpu=name --format=csv,noheader').read())

def getGPUArch(argument):
  try:
    argument = argument.strip()
    # All Colab GPUs
    archTypes = {
        "Tesla V100-SXM2-16GB": "-gencode arch=compute_70,code=[sm_70,compute_70]",
        "Tesla K80": "-gencode arch=compute_37,code=sm_37",
        "Tesla T4": "-gencode arch=compute_75,code=[sm_75,compute_75]",
        "Tesla P40": "-gencode arch=compute_61,code=sm_61",
        "Tesla P4": "-gencode arch=compute_61,code=sm_61",
        "Tesla P100-PCIE-16GB": "-gencode arch=compute_60,code=sm_60"

      }
    return archTypes[argument]
  except KeyError:
    return "GPU must be added to GPU Commands"
os.environ['ARCH_VALUE'] = getGPUArch(os.environ['GPU_TYPE'])

print("GPU Type: " + os.environ['GPU_TYPE'])
print("ARCH Value: " + os.environ['ARCH_VALUE'])
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# Sun Jun  5 08:03:44 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# GPU Type: Tesla T4
#
# ARCH Value: -gencode arch=compute_75,code=[sm_75,compute_75]

# %% [markdown]
# # Installing Darknet for YOLOv4 on Colab

# %%
## Remove if "darknet" already exists
if os.path.isdir(os.path.join(main_directory,"darknet/"))==True:
  shutil.rmtree(os.path.join(main_directory,"darknet"))  


## Clone Darknet files from Github
# !git clone https://github.com/roboflow-ai/darknet.git   


## Install environment from 'Makefile'
os.chdir(os.path.join(main_directory,"darknet"))     # change directory to '/content/drive/MyDrive/Yolo_tiny/darknet'
"""
Note: 
      If you are on Colab Pro this works on a P100 GPU
      If you are on Colab free, you may need to change the Makefile for the K80 GPU
      this goes for any GPU, you need to change the Makefile to inform darknet which GPU you are running on.
"""
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !sed -i "s/ARCH= -gencode arch=compute_60,code=sm_60/ARCH= ${ARCH_VALUE}/g" Makefile
# !make


## Download newly released yolov4-tiny weights
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.conv.29
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 13289, done.
# remote: Total 13289 (delta 0), reused 0 (delta 0), pack-reused 13289
# Receiving objects: 100% (13289/13289), 12.17 MiB | 8.37 MiB/s, done.
# Resolving deltas: 100% (9047/9047), done.
# Checking out files: 100% (2002/2002), done.
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1367:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1371:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1375:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1378:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2039:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2038:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:224:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:276:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:276:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:276:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:286:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:307:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:322:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:328:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1204:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:77:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:77:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:287:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:287:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1134:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:984:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:610:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1573:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:451:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:544:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:657:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:655:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1276:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1275:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1792:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:191:9: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#          if (l.x_gpu)                   cuda_free(l.x_gpu);  l.x_gpu = NULL;
#          ^~
# ./src/layer.c:191:61: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#          if (l.x_gpu)                   cuda_free(l.x_gpu);  l.x_gpu = NULL;
#                                                              ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:138:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:831:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1261:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1261:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:58:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:57:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:61:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:95:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:104:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:371:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4811:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘forward_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:460:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu(1389): warning: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(1038): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1082): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1686): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1082:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# ./src/network_kernels.cu(359): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(368): warning: variable "im" was set but never used
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:359:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# ./src/network_kernels.cu:368:7: warning: variable ‘im’ set but not used [-Wunused-but-set-variable]
#          image im;
#        ^
# nvcc -gencode arch=compute_75,code=[sm_75,compute_75] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# # Set up Custom Dataset for YOLOv4

# %%
# %mkdir data/obj

# ## Copy train,test,valid zip files & unzip
# %cp /content/drive/MyDrive/Yolo_tiny/train.zip /content
# %cp /content/drive/MyDrive/Yolo_tiny/valid.zip /content
# %cp /content/drive/MyDrive/Yolo_tiny/test.zip /content
# %cp /content/drive/MyDrive/Yolo_tiny/obj.names data/  # copy obj.names

# !unzip /content/train.zip -d /content
# !unzip /content/valid.zip -d /content
# !unzip /content/test.zip -d data


## Set up training file directories for custom dataset (copy image and labels)
# %cp /content/train/*.jpg data/obj/
# %cp /content/valid/*.jpg data/obj/
# %cp /content/train/*.txt data/obj/
# %cp /content/valid/*.txt data/obj/


with open('data/obj.data', 'w') as out:
  out.write('classes = 1\n')
  out.write('train = data/train.txt\n')
  out.write('valid = data/valid.txt\n')
  out.write('names = data/obj.names\n')
  out.write('backup = /content/drive/MyDrive/Yolo_tiny/models/')

## write train file (just the image list)
with open('data/train.txt', 'w') as out:
  for img in [f for f in os.listdir('/content/train') if f.endswith('jpg')]:
    out.write('data/obj/' + img + '\n')

## write the valid file (just the image list)
with open('data/valid.txt', 'w') as out:
  for img in [f for f in os.listdir('/content/valid') if f.endswith('jpg')]:
    out.write('data/obj/' + img + '\n')

# %% [markdown]
# # Write Custom Training Config for YOLOv4

# %%
## we build iteratively from base config files. This is the same file shape as cfg/yolo-obj.cfg
"""
Note:
  change line max_batches to (classes*2000 but not less than number of training images, and not less than 6000), f.e. max_batches=6000 if you train for 3 classes
  change line steps to 80% and 90% of max_batches, f.e. steps=4800,5400

"""
def file_len(fname):
  with open(fname) as f:
    for i, l in enumerate(f):
      pass
  return i + 1

num_classes = 1                                 # Number of classes
if num_classes*2000>=6000:
  max_batches = num_classes*2000
else:
  max_batches = 6000
steps1 = .8 * max_batches
steps2 = .9 * max_batches
steps_str = str(steps1)+','+str(steps2)
num_filters = (num_classes + 5) * 3
print("writing config for a custom YOLOv4 detector detecting number of classes: " + str(num_classes))


if os.path.exists('./cfg/custom-yolov4-tiny-detector.cfg'): os.remove('./cfg/custom-yolov4-tiny-detector.cfg')
@register_line_cell_magic        # customize iPython writefile so we can write variables
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))
# Out:
# writing config for a custom YOLOv4 detector detecting number of classes: 1

# %%
# %%writetemplate ./cfg/custom-yolov4-tiny-detector.cfg
# [net]
# # Testing
# #batch=1
# #subdivisions=1
# # Training
# batch=64
# subdivisions=24
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.00261
# burn_in=1000
# max_batches = 6000
# policy=steps
# steps={steps_str}
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers=-1
# groups=2
# group_id=1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers = -1,-2
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers = -6,-1
#
# [maxpool]
# size=2
# stride=2
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers=-1
# groups=2
# group_id=1
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers = -1,-2
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers = -6,-1
#
# [maxpool]
# size=2
# stride=2
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers=-1
# groups=2
# group_id=1
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers = -1,-2
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [route]
# layers = -6,-1
#
# [maxpool]
# size=2
# stride=2
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# ##################################
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters={num_filters}
# activation=linear
#
#
#
# [yolo]
# mask = 3,4,5
# anchors = 10,14,  23,27,  37,58,  81,82,  135,169,  344,319
# classes={num_classes}
# num=6
# jitter=.3
# scale_x_y = 1.05
# cls_normalizer=1.0
# iou_normalizer=0.07
# iou_loss=ciou
# ignore_thresh = .7
# truth_thresh = 1
# random=0
# nms_kind=greedynms
# beta_nms=0.6
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 23
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters={num_filters}
# activation=linear
#
# [yolo]
# mask = 1,2,3
# anchors = 10,14,  23,27,  37,58,  81,82,  135,169,  344,319
# classes={num_classes}
# num=6
# jitter=.3
# scale_x_y = 1.05
# cls_normalizer=1.0
# iou_normalizer=0.07
# iou_loss=ciou
# ignore_thresh = .7
# truth_thresh = 1
# random=0
# nms_kind=greedynms
# beta_nms=0.6
#
#
# %cat cfg/custom-yolov4-tiny-detector.cfg

# %% [markdown]
# # Train Custom YOLOv4 Detector

# %%
# !./darknet detector train data/obj.data cfg/custom-yolov4-tiny-detector.cfg yolov4-tiny.conv.29 -dont_show -map
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  compute_capability = 750, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 24, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
#    9 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
#   10 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   11 route  10 		                       1/2 ->   52 x  52 x  64
#   12 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   13 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   14 route  13 12 	                           ->   52 x  52 x 128
#   15 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   16 route  10 15 	                           ->   52 x  52 x 256
#   17 max                2x 2/ 2     52 x  52 x 256 ->   26 x  26 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   19 route  18 		                       1/2 ->   26 x  26 x 128
#   20 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   21 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   22 route  21 20 	                           ->   26 x  26 x 256
#   23 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   24 route  18 23 	                           ->   26 x  26 x 512
#   25 max                2x 2/ 2     26 x  26 x 512 ->   13 x  13 x 512 0.000 BF
#   26 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   27 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   28 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   29 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   13 x  13 x 256
#   32 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   33 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   34 route  33 23 	                           ->   26 x  26 x 384
#   35 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   36 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Unused field: '%catcfg/custom-yolov4-tiny-detector.cfg = (null)'
# Total BFLOPS 6.787
# avg_outputs = 299663
#  Allocate additional workspace_size = 26.22 MB
# custom-yolov4-tiny-detector
#  compute_capability = 750, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 2, batch = 48, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
#    9 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
#   10 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   11 route  10 		                       1/2 ->   52 x  52 x  64
#   12 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   13 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   14 route  13 12 	                           ->   52 x  52 x 128
#   15 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   16 route  10 15 	                           ->   52 x  52 x 256
#   17 max                2x 2/ 2     52 x  52 x 256 ->   26 x  26 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   19 route  18 		                       1/2 ->   26 x  26 x 128
#   20 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   21 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   22 route  21 20 	                           ->   26 x  26 x 256
#   23 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   24 route  18 23 	                           ->   26 x  26 x 512
#   25 max                2x 2/ 2     26 x  26 x 512 ->   13 x  13 x 512 0.000 BF
#   26 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   27 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   28 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   29 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   13 x  13 x 256
#   32 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   33 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   34 route  33 23 	                           ->   26 x  26 x 384
#   35 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   36 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Unused field: '%catcfg/custom-yolov4-tiny-detector.cfg = (null)'
# Total BFLOPS 6.787
# avg_outputs = 299663
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from yolov4-tiny.conv.29...
#  seen 64, trained: 0 K-images (0 Kilo-batches_64)
# Done! Loaded 29 layers from weights-file
# Learning Rate: 0.00261, Momentum: 0.9, Decay: 0.0005
#  Create 6 permanent cpu-threads
# Loaded: 2.254072 seconds
#
#  (next mAP calculation at 1000 iterations)
#  1: 430.066071, 430.066071 avg loss, 0.000000 rate, 0.777432 seconds, 48 images, -1.000000 hours left
# Loaded: 1.542715 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  2: 430.429596, 430.102417 avg loss, 0.000000 rate, 0.657592 seconds, 96 images, 5.051703 hours left
# Loaded: 1.592667 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  3: 430.284058, 430.120575 avg loss, 0.000000 rate, 0.664153 seconds, 144 images, 5.037846 hours left
# Loaded: 1.572803 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  4: 429.515594, 430.060089 avg loss, 0.000000 rate, 0.652486 seconds, 192 images, 5.025063 hours left
# Loaded: 1.540051 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  5: 430.434448, 430.097534 avg loss, 0.000000 rate, 0.631184 seconds, 240 images, 5.011876 hours left
# Loaded: 1.516481 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  6: 430.477570, 430.135529 avg loss, 0.000000 rate, 0.638810 seconds, 288 images, 4.997915 hours left
# Loaded: 1.600405 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  7: 430.041595, 430.126129 avg loss, 0.000000 rate, 0.678145 seconds, 336 images, 4.983822 hours left
# Loaded: 1.440223 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  8: 429.967896, 430.110321 avg loss, 0.000000 rate, 0.671905 seconds, 384 images, 4.971916 hours left
# Loaded: 1.509290 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  9: 430.059601, 430.105255 avg loss, 0.000000 rate, 0.595013 seconds, 432 images, 4.957414 hours left
# Loaded: 1.543269 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  10: 430.429169, 430.137634 avg loss, 0.000000 rate, 0.644020 seconds, 480 images, 4.942859 hours left
# Loaded: 1.517047 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  11: 430.663208, 430.190186 avg loss, 0.000000 rate, 0.582542 seconds, 528 images, 4.929825 hours left
# Loaded: 1.415561 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  12: 430.403656, 430.211548 avg loss, 0.000000 rate, 0.744054 seconds, 576 images, 4.915456 hours left
# Loaded: 1.359661 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  13: 430.667267, 430.257111 avg loss, 0.000000 rate, 0.631629 seconds, 624 images, 4.902224 hours left
# Loaded: 1.478127 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  14: 430.113678, 430.242767 avg loss, 0.000000 rate, 0.632208 seconds, 672 images, 4.886319 hours left
# Loaded: 1.436750 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#
seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  61: 412.576874, 420.519897 avg loss, 0.000000 rate, 0.616123 seconds, 2928 images, 4.338754 hours left
# Loaded: 1.304481 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  62: 411.808868, 419.648804 avg loss, 0.000000 rate, 0.628342 seconds, 2976 images, 4.328243 hours left
# Loaded: 1.366469 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  63: 410.217163, 418.705627 avg loss, 0.000000 rate, 0.625960 seconds, 3024 images, 4.316842 hours left
# Loaded: 1.451945 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  64: 408.676147, 417.702667 avg loss, 0.000000 rate, 0.572679 seconds, 3072 images, 4.306532 hours left
# Loaded: 1.507709 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  65: 406.875366, 416.619934 avg loss, 0.000000 rate, 0.601708 seconds, 3120 images, 4.296852 hours left
# Loaded: 1.512690 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  66: 404.518951, 415.409851 avg loss, 0.000000 rate, 0.642124 seconds, 3168 images, 4.288659 hours left
# Loaded: 1.362114 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  67: 402.145599, 414.083435 avg loss, 0.000000 rate, 0.612478 seconds, 3216 images, 4.281292 hours left
# Loaded: 1.463662 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  68: 400.739716, 412.749054 avg loss, 0.000000 rate, 0.655065 seconds, 3264 images, 4.271022 hours left
# Loaded: 1.273445 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  69: 398.222260, 411.296387 avg loss, 0.000000 rate, 0.580544 seconds, 3312 images, 4.263224 hours left
# Loaded: 1.490211 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  70: 396.498779, 409.816620 avg loss, 0.000000 rate, 0.584940 seconds, 3360 images, 4.251253 hours left
# Loaded: 1.524011 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  71: 393.726654, 408.207611 avg loss, 0.000000 rate, 0.552025 seconds, 3408 images, 4.242923 hours left
# Loaded: 1.517014 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  72: 391.030975, 406.489960 avg loss, 0.000000 rate, 0.584113 seconds, 3456 images, 4.234686 hours left
# Loaded: 1.334126 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  73: 387.969696, 404.637939 avg loss, 0.000000 rate, 0.606788 seconds, 3504 images, 4.226998 hours left
# Loaded: 1.323321 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  74: 385.455597, 402.719696 avg loss, 0.000000 rate, 0.547746 seconds, 3552 images, 4.216684 hours left
# Loaded: 1.390828 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  75: 382.212494, 400.668976 avg loss, 0.000000 rate, 0.596311 seconds, 3600 images, 4.205317 hours left
# Loaded: 1.340392 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  76: 379.514038, 398.553467 avg loss, 0.000000 rate, 0.628084 seconds, 3648 images, 4.195970 hours left
# Loaded: 1.277183 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  77: 375.759613, 396.274078 avg loss, 0.000000 rate, 0.578259 seconds, 3696 images, 4.186402 hours left
# Loaded: 1.440166 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  78: 372.616974, 393.908356 avg loss, 0.000000 rate, 0.630909 seconds, 3744 images, 4.175066 hours left
# Loaded: 1.419968 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  79: 368.372437, 391.354767 avg loss, 0.000000 rate, 0.594628 seconds, 3792 images, 4.167385 hours left
# Loaded: 1.458322 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  80: 364.705109, 388.689789 avg loss, 0.000000 rate, 0.621720 seconds, 3840 images, 4.158846 hours left
# Loaded: 1.482549 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  81: 360.749603, 385.895782 avg loss, 0.000000 rate, 0.601105 seconds, 3888 images, 4.151463 hours left
# Loaded: 1.455429 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  82: 356.688995, 382.975098 avg loss, 0.000000 rate, 0.625416 seconds, 3936 images, 4.144208 hours left
# Loaded: 1.509713 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  83: 352.473541, 379.924957 avg loss, 0.000000 rate, 0.656028 seconds, 3984 images, 4.136974 hours left
# Loaded: 1.498396 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  84: 347.990692, 376.731537 avg loss, 0.000000 rate, 0.576743 seconds, 4032 images, 4.131201 hours left
# Loaded: 1.506831 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  85: 343.183868, 373.376770 avg loss, 0.000000 rate, 0.612053 seconds, 4080 images, 4.123990 hours left
# Loaded: 1.465554 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  86: 337.869232, 369.826019 avg loss, 0.000000 rate, 0.589830 seconds, 4128 images, 4.117565 hours left
# Loaded: 1.432119 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  87: 333.304596, 366.173889 avg loss, 0.000000 rate, 0.616470 seconds, 4176 images, 4.110156 hours left
# Loaded: 1.456711 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  88: 328.268341, 362.383331 avg loss, 0.000000 rate, 0.600403 seconds, 4224 images, 4.102703 hours left
# Loaded: 1.424098 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  89: 322.523346, 358.397339 avg loss, 0.000000 rate, 0.644793 seconds, 4272 images, 4.095459 hours left
# Loaded: 1.435158 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  90: 317.283264, 354.285919 avg loss, 0.000000 rate, 0.591875 seconds, 4320 images, 4.088475 hours left
# Loaded: 1.433267 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  91: 311.221069, 349.979431 avg loss, 0.000000 rate, 0.580455 seconds, 4368 images, 4.080928 hours left
# Loaded: 2.114003 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  92: 305.548492, 345.536346 avg loss, 0.000000 rate, 1.076364 seconds, 4416 images, 4.073308 hours left
# Loaded: 1.975745 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  93: 299.155090, 340.898224 avg loss, 0.000000 rate, 0.748812 seconds, 4464 images, 4.084933 hours left
# Loaded: 1.353101 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  94: 293.007355, 336.109131 avg loss, 0.000000 rate, 0.614071 seconds, 4512 images, 4.088790 hours left
# Loaded: 1.422484 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  95: 286.512085, 331.149414 avg loss, 0.000000 rate, 0.623598 seconds, 4560 images, 4.080175 hours left
# Loaded: 1.427314 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  96: 280.239075, 326.058380 avg loss, 0.000000 rate, 0.619045 seconds, 4608 images, 4.072935 hours left
# Loaded: 1.427114 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  97: 273.602356, 320.812775 avg loss, 0.000000 rate, 0.609856 seconds, 4656 images, 4.065766 hours left
# Loaded: 1.419853 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  98: 266.738556, 315.405365 avg loss, 0.000000 rate, 0.598435 seconds, 4704 images, 4.058510 hours left
# Loaded: 1.402810 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  99: 260.075348, 309.872375 avg loss, 0.000000 rate, 0.610613 seconds, 4752 images, 4.051015 hours left
# Loaded: 1.514180 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  100: 252.488770, 304.134003 avg loss, 0.000000 rate, 0.630869 seconds, 4800 images, 4.043509 hours left
# Saving weights to /content/drive/MyDrive/Yolo_tiny/models//custom-yolov4-tiny-detector_last.weights
# Loaded: 0.018748 seconds
#
#  (next mAP calculation at 1000 iterations)
#  101: 245.823135, 298.302917 avg loss, 0.000000 rate, 0.787064 seconds, 4848 images, 4.038229 hours left
# Loaded: 1.643497 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  102: 238.362915, 292.308929 avg loss, 0.000000 rate, 0.733782 seconds, 4896 images, 4.011091 hours left
# Loaded: 1.908985 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  103: 231.221359, 286.200165 avg loss, 0.000000 rate, 0.807508 seconds, 4944 images, 4.009928 hours left
# Loaded: 1.503790 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  104: 223.779053, 279.958069 avg loss, 0.000000 rate, 0.573521 seconds, 4992 images, 4.014327 hours left
# Loaded: 1.339585 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#
seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  128: 69.499153, 121.827194 avg loss, 0.000001 rate, 0.674613 seconds, 6144 images, 3.849024 hours left
# Loaded: 1.345033 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  129: 65.388344, 116.183311 avg loss, 0.000001 rate, 0.599484 seconds, 6192 images, 3.844923 hours left
# Loaded: 1.419314 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  130: 61.184525, 110.683434 avg loss, 0.000001 rate, 0.602352 seconds, 6240 images, 3.838186 hours left
# Loaded: 1.342197 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  131: 57.826817, 105.397774 avg loss, 0.000001 rate, 0.640400 seconds, 6288 images, 3.832769 hours left
# Loaded: 1.290399 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  132: 54.164825, 100.274475 avg loss, 0.000001 rate, 0.589973 seconds, 6336 images, 3.826862 hours left
# Loaded: 1.410253 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  133: 49.806324, 95.227661 avg loss, 0.000001 rate, 0.603426 seconds, 6384 images, 3.819244 hours left
# Loaded: 1.464413 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  134: 46.614517, 90.366348 avg loss, 0.000001 rate, 0.580969 seconds, 6432 images, 3.813869 hours left
# Loaded: 1.356293 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  135: 43.941055, 85.723816 avg loss, 0.000001 rate, 0.649333 seconds, 6480 images, 3.809059 hours left
# Loaded: 1.402943 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  136: 41.029186, 81.254356 avg loss, 0.000001 rate, 0.655317 seconds, 6528 images, 3.803646 hours left
# Loaded: 1.220197 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  137: 38.673695, 76.996292 avg loss, 0.000001 rate, 0.573292 seconds, 6576 images, 3.799137 hours left
# Loaded: 1.446398 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  138: 35.999863, 72.896652 avg loss, 0.000001 rate, 0.561506 seconds, 6624 images, 3.790355 hours left
# Loaded: 1.324732 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  139: 33.794643, 68.986450 avg loss, 0.000001 rate, 0.588075 seconds, 6672 images, 3.785147 hours left
# Loaded: 1.349632 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  140: 31.738203, 65.261627 avg loss, 0.000001 rate, 0.575414 seconds, 6720 images, 3.778525 hours left
# Loaded: 1.364350 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  141: 29.613047, 61.696770 avg loss, 0.000001 rate, 0.592285 seconds, 6768 images, 3.772077 hours left
# Loaded: 1.354022 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  142: 27.459770, 58.273071 avg loss, 0.000001 rate, 0.585673 seconds, 6816 images, 3.766201 hours left
# Loaded: 1.337025 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  143: 25.834581, 55.029221 avg loss, 0.000001 rate, 0.617391 seconds, 6864 images, 3.760103 hours left
# Loaded: 1.294528 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  144: 24.182497, 51.944550 avg loss, 0.000001 rate, 0.561073 seconds, 6912 images, 3.754300 hours left
# Loaded: 1.354028 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  145: 22.599581, 49.010052 avg loss, 0.000001 rate, 0.553007 seconds, 6960 images, 3.747089 hours left
# Loaded: 1.422563 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  146: 20.891562, 46.198204 avg loss, 0.000001 rate, 0.594955 seconds, 7008 images, 3.740636 hours left
# Loaded: 1.384153 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  147: 19.497505, 43.528133 avg loss, 0.000001 rate, 0.575392 seconds, 7056 images, 3.736037 hours left
# Loaded: 1.416058 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  148: 18.499655, 41.025284 avg loss, 0.000001 rate, 0.580971 seconds, 7104 images, 3.730536 hours left
# Loaded: 1.399668 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  149: 17.366140, 38.659370 avg loss, 0.000001 rate, 0.596473 seconds, 7152 images, 3.725693 hours left
# Loaded: 1.431414 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  150: 16.134130, 36.406845 avg loss, 0.000001 rate, 0.579395 seconds, 7200 images, 3.720880 hours left
# Loaded: 1.362986 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  151: 15.242148, 34.290375 avg loss, 0.000001 rate, 0.601386 seconds, 7248 images, 3.716347 hours left
# Loaded: 1.377718 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  152: 14.206029, 32.281940 avg loss, 0.000001 rate, 0.566915 seconds, 7296 images, 3.711100 hours left
# Loaded: 1.298122 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  153: 13.532866, 30.407034 avg loss, 0.000001 rate, 0.586616 seconds, 7344 images, 3.705579 hours left
# Loaded: 1.348033 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  154: 12.454426, 28.611773 avg loss, 0.000001 rate, 0.669746 seconds, 7392 images, 3.699136 hours left
# Loaded: 1.183216 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  155: 11.959533, 26.946548 avg loss, 0.000002 rate, 0.602412 seconds, 7440 images, 3.694911 hours left
# Loaded: 1.335210 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  156: 11.118787, 25.363771 avg loss, 0.000002 rate, 0.587670 seconds, 7488 images, 3.686954 hours left
# Loaded: 1.420835 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  157: 10.301674, 23.857561 avg loss, 0.000002 rate, 0.575892 seconds, 7536 images, 3.681300 hours left
# Loaded: 1.340879 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  158: 9.871273, 22.458933 avg loss, 0.000002 rate, 0.568440 seconds, 7584 images, 3.676895 hours left
# Loaded: 1.376563 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  159: 9.402917, 21.153332 avg loss, 0.000002 rate, 0.609838 seconds, 7632 images, 3.671111 hours left
# Loaded: 1.304109 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  160: 8.939104, 19.931910 avg loss, 0.000002 rate, 0.565609 seconds, 7680 images, 3.666629 hours left
# Loaded: 1.320303 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  161: 8.301860, 18.768904 avg loss, 0.000002 rate, 0.591550 seconds, 7728 images, 3.660294 hours left
# Loaded: 1.348754 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  162: 7.950490, 17.687063 avg loss, 0.000002 rate, 0.609048 seconds, 7776 images, 3.654701 hours left
# Loaded: 1.306536 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  163: 7.624938, 16.680851 avg loss, 0.000002 rate, 0.564539 seconds, 7824 images, 3.649904 hours left
# Loaded: 1.380295 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  164: 6.959940, 15.708760 avg loss, 0.000002 rate, 0.576735 seconds, 7872 images, 3.643742 hours left
# Loaded: 1.418335 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  165: 6.554672, 14.793351 avg loss, 0.000002 rate, 0.650329 seconds, 7920 images, 3.639031 hours left
# Loaded: 1.298096 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  166: 6.360699, 13.950086 avg loss, 0.000002 rate, 0.567352 seconds, 7968 images, 3.636171 hours left
# Loaded: 1.483386 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  167: 5.844752, 13.139552 avg loss, 0.000002 rate, 0.596505 seconds, 8016 images, 3.630040 hours left
# Loaded: 1.423357 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  168: 5.683834, 12.393980 avg loss, 0.000002 rate, 0.643217 seconds, 8064 images, 3.627440 hours left
# Loaded: 1.296186 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  169: 5.540021, 11.708584 avg loss, 0.000002 rate, 0.606739 seconds, 8112 images, 3.624645 hours left
# Loaded: 1.373887 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  170: 5.178481, 11.055573 avg loss, 0.000002 rate, 0.555833 seconds, 8160 images, 3.619226 hours left
# Loaded: 1.409319 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  171: 4.910684, 10.441085 avg loss, 0.000002 rate, 0.573089 seconds, 8208 images, 3.614284 hours left
# Loaded: 1.366175 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  172: 4.765862, 9.873563 avg loss, 0.000002 rate, 0.560664 seconds, 8256 images, 3.610241 hours left
# Loaded: 1.400422 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  173: 4.613676, 9.347574 avg loss, 0.000002 rate, 0.550561 seconds, 8304 images, 3.605332 hours left
# Loaded: 1.415121 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  174: 4.334760, 8.846292 avg loss, 0.000002 rate, 0.610373 seconds, 8352 images, 3.600924 hours left
# Loaded: 1.244694 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  175: 4.429156, 8.404579 avg loss, 0.000002 rate, 0.624783 seconds, 8400 images, 3.597695 hours left
# Loaded: 1.385474 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  176: 3.934375, 7.957559 avg loss, 0.000003 rate, 0.603474 seconds, 8448 images, 3.591967 hours left
# Loaded: 1.338117 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  177: 3.814258, 7.543229 avg loss, 0.000003 rate, 0.629105 seconds, 8496 images, 3.588225 hours left
# Loaded: 1.344134 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  178: 3.704989, 7.159405 avg loss, 0.000003 rate, 0.629316 seconds, 8544 images, 3.584163 hours left
# Loaded: 1.337804 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  179: 3.565619, 6.800026 avg loss, 0.000003 rate, 0.619660 seconds, 8592 images, 3.580237 hours left
# Loaded: 1.678242 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  180: 3.411834, 6.461207 avg loss, 0.000003 rate, 0.990461 seconds, 8640 images, 3.576086 hours left
# Loaded: 2.106258 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  181: 3.566796, 6.171766 avg loss, 0.000003 rate, 0.688512 seconds, 8688 images, 3.583470 hours left
# Loaded: 1.288535 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  182: 3.249069, 5.879496 avg loss, 0.000003 rate, 0.599855 seconds, 8736 images, 3.592810 hours left
# Loaded: 1.357204 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  183: 3.112593, 5.602806 avg loss, 0.000003 rate, 0.563033 seconds, 8784 images, 3.587401 hours left
# Loaded: 1.427845 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  184: 2.874432, 5.329968 avg loss, 0.000003 rate, 0.600710 seconds, 8832 images, 3.582555 hours left
# Loaded: 1.382191 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
# ...
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1003: 0.253780, 0.264644 avg loss, 0.002610 rate, 0.567497 seconds, 48144 images, 2.741090 hours left
# Loaded: 1.282286 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1004: 0.290794, 0.267259 avg loss, 0.002610 rate, 0.614136 seconds, 48192 images, 2.740194 hours left
# Loaded: 1.281519 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1005: 0.263830, 0.266916 avg loss, 0.002610 rate, 0.594538 seconds, 48240 images, 2.739110 hours left
# Loaded: 1.406670 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1006: 0.231444, 0.263369 avg loss, 0.002610 rate, 0.597314 seconds, 48288 images, 2.737749 hours left
# Loaded: 1.489451 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1007: 0.282542, 0.265286 avg loss, 0.002610 rate, 0.651706 seconds, 48336 images, 2.738172 hours left
# Loaded: 1.204930 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1008: 0.207664, 0.259524 avg loss, 0.002610 rate, 0.535872 seconds, 48384 images, 2.740487 hours left
# Loaded: 1.453732 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1009: 0.336381, 0.267210 avg loss, 0.002610 rate, 0.594233 seconds, 48432 images, 2.737221 hours left
# Loaded: 1.343172 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1010: 0.297349, 0.270224 avg loss, 0.002610 rate, 0.617841 seconds, 48480 images, 2.738242 hours left
# Loaded: 1.195478 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1011: 0.399801, 0.283181 avg loss, 0.002610 rate, 0.598443 seconds, 48528 images, 2.738042 hours left
# Loaded: 1.300720 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1012: 0.231339, 0.277997 avg loss, 0.002610 rate, 0.606945 seconds, 48576 images, 2.735523 hours left
# Loaded: 1.271197 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1013: 0.208385, 0.271036 avg loss, 0.002610 rate, 0.594223 seconds, 48624 images, 2.734599 hours left
# Loaded: 1.247599 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  
seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1060: 0.231268, 0.245745 avg loss, 0.002610 rate, 0.576905 seconds, 50880 images, 2.696809 hours left
# Loaded: 1.292675 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1100 iterations)
#  Last accuracy mAP@0.5 = 98.33 %, best = 98.33 %
#  1061: 0.238492, 0.245019 avg loss, 0.002610 rate, 0.583634 seconds, 50928 images, 2.696606 hours left
# Loaded: 1.286862 seconds - performance bottleneck on CPU or Disk HDD/SSD

# %% [markdown]
# ## Resume the Training

# %%
## All Available trained weights
# !ls /content/drive/MyDrive/Yolo_tiny/models
# Out:
# custom-yolov4-tiny-detector_1000.weights
# custom-yolov4-tiny-detector_2000.weights
# custom-yolov4-tiny-detector_best.weights
# custom-yolov4-tiny-detector_last.weights

# %%
## kick off training from where it last saved
#!./darknet detector train data/obj.data cfg/custom-yolov4-tiny-detector.cfg /content/drive/MyDrive/Yolo_tiny/models/XXXXXXX.weights -dont_show -map
# !./darknet detector train data/obj.data cfg/custom-yolov4-tiny-detector.cfg /content/drive/MyDrive/Yolo_tiny/models/custom-yolov4-tiny-detector_last.weights -dont_show -map

# %% [markdown]
# # Infer Custom Objects with Saved YOLOv4 Weights

# %%
#define utility function
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
#check if weigths have saved yet
#backup houses the last weights for our detector
#(file yolo-obj_last.weights will be saved to the build\darknet\x64\backup\ for each 100 iterations)
#(file yolo-obj_xxxx.weights will be saved to the build\darknet\x64\backup\ for each 1000 iterations)
#After training is complete - get result yolo-obj_final.weights from path build\darknet\x64\bac
# !ls /content/drive/MyDrive/Yolo_tiny/models
#if it is empty you haven't trained for long enough yet, you need to train for at least 100 iterations
# Out:
# custom-yolov4-tiny-detector_1000.weights
# custom-yolov4-tiny-detector_2000.weights
# custom-yolov4-tiny-detector_3000.weights
# custom-yolov4-tiny-detector_4000.weights
# custom-yolov4-tiny-detector_5000.weights
# custom-yolov4-tiny-detector_6000.weights
# custom-yolov4-tiny-detector_best.weights
# custom-yolov4-tiny-detector_final.weights
# custom-yolov4-tiny-detector_last.weights

# %%
#coco.names is hardcoded somewhere in the detector
# %cp data/obj.names data/coco.names

# %%
#/test has images that we can test our detector on
test_images = [f for f in os.listdir('data/test/') if f.endswith('.jpg')]
import random
img_path = "data/test/" + random.choice(test_images);
print('================',img_path)


#test out our detector!
# !./darknet detect cfg/custom-yolov4-tiny-detector.cfg /content/drive/MyDrive/yolo/models/custom-yolov4-tiny-detector_best.weights {img_path} -dont-show -thresh 0.50
#imShow('/content/darknet/predictions.jpg')
# Out:
# ================ data/test/376.jpg
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 750, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 24, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
#    9 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
#   10 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   11 route  10 		                       1/2 ->   52 x  52 x  64
#   12 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   13 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   14 route  13 12 	                           ->   52 x  52 x 128
#   15 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   16 route  10 15 	                           ->   52 x  52 x 256
#   17 max                2x 2/ 2     52 x  52 x 256 ->   26 x  26 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   19 route  18 		                       1/2 ->   26 x  26 x 128
#   20 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   21 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   22 route  21 20 	                           ->   26 x  26 x 256
#   23 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   24 route  18 23 	                           ->   26 x  26 x 512
#   25 max                2x 2/ 2     26 x  26 x 512 ->   13 x  13 x 512 0.000 BF
#   26 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   27 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   28 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   29 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   13 x  13 x 256
#   32 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   33 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   34 route  33 23 	                           ->   26 x  26 x 384
#   35 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   36 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 6.787
# avg_outputs = 299663
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from /content/drive/MyDrive/yolo/models/custom-yolov4-tiny-detector_best.weights...
#  seen 64, trained: 67 K-images (1 Kilo-batches_64)
# Done! Loaded 38 layers from weights-file
# data/test/376.jpg: Predicted in 5.262000 milli-seconds.
# 0: 97%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:1304): Gtk-WARNING **: 20:16:58.316: cannot open display:

# %% [markdown]
# # Testing on Video

# %%
## List all Available Input Videos
# !ls /content/drive/MyDrive/Yolo_tiny/input_video

# %%
selected_video="barcode.mp4"

for video in os.listdir(r'/content/drive/MyDrive/yolo/input_video'):

# %%
input_video_path = "/content/drive/MyDrive/yolo/input_video/barcode.mp4"
output_video_path = "/content/drive/MyDrive/yolo/output_video/barcode.mp4"

# %%
# !./darknet detector demo data/obj.data cfg/custom-yolov4-tiny-detector.cfg /content/drive/MyDrive/yolo/models/custom-yolov4-tiny-detector_best.weights $input_video_path -i 0 -out_filename $output_video_path -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:31.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:31.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.6 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.6 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.1 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.2 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.2 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.2 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.3 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:26.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:26.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.6 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.5 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.3 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:24.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.1 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.5 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:24.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:24.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.1
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
